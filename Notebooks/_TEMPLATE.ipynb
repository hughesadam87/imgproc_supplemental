# %% [markdown]
# - *Adam Hughes*
# - **::DATE::**
# - *George Washington University*

# %% [markdown]
# # TITLE

# %% [markdown]
# ### <font color='purple'>Objective</font>

# %% [markdown]
# ::**DESCRIPTION OF OBJECTIVE**::

# %% [markdown]
# ### <font color='purple'>Environment Setup</font>

# %% [markdown]
# Configure notebook style (see NBCONFIG.ipynb), add imports and paths.

# %%
filename = "./NBCONFIG.ipynb"
# %run "NBCONFIG.ipynb"

import os.path as op
def digdir(path):
    """ Set relative path to digitization folder to use files/images therein"""
    return op.join( '../images/Digitization/', path)
# Out:
# ERROR: File `u'NBCONFIG.ipynb.py'` not found.

# %% [markdown]
# #### Step 1: ::NAME::

# %% [markdown]
# Explanation of step 1

# %% [markdown]
# ### References

# %% [markdown]
# - [1] : foo bar baz

# %% [markdown]
# ### Related

# %% [markdown]
# - Louic NB style: http://blog.louic.nl/?p=683

# %% [markdown]
# ### Redistribution

# %% [markdown]
# This notebook is free for redistribution.  If using as reference, please cite as:
#
# - ???

# %%
from pyparty.data import gwu
showim(gwu());

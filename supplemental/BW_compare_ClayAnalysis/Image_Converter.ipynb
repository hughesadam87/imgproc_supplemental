# %%
# %run NBCONFIG.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['title', 'imread']
# `%matplotlib` prevents importing * from pylab and numpy
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
#
# div #notebook { /* centre the content */
#     background: #FFFFF0;  /* IVORY */
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
#
# div.text_cell_render {  /*Markdown cells */
#     font-family: Computer Modern Roman;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0; /*What is this */
#     padding: 0.05; /*Spacing between cells*/
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0.05;
# }
#
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
# ...

# %%
from skimage.io import imread
#from pyparty.data import nanolabels
from pyparty.plots import splot, showim 

NANOLABELS = imread('f6_30000_thresh_bin.png')
NAMES = ('cluster', 'flats', 'dimers', 'singles')
showim(NANOLABELS, 'spectral', title='Labeled Nanoparticles')

# %%
binary = NANOLABELS > 0
area = binary.shape[0]*binary.shape[1]
white = binary.sum()

title = 'f6_30000_cropped: Coverage = %.2f%%' % (100.0* (float(white)/area) )
imshow(binary)
plt.title(title)
plt.savefig('f6_30000_ilastik_binary')
